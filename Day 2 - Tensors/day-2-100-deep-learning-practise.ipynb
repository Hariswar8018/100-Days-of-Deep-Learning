# %% [markdown]
# DAY 2/100 — DEEP LEARNING PRACTICE
# TOPIC: TENSORS (PyTorch)
# =========================================================
#
# INSTRUCTIONS:
# 1. Read each QUESTION carefully.
# 2. Write your answer in the space provided.
# 3. After finishing ALL questions, scroll down
#    to the ANSWER SECTION and verify.
#
#
# ### Download link : https://www.kaggle.com/code/samasiayushman/day-2-100-deep-learning-practise/

# %% [markdown]
# #### Run this Imports ! Important

# %%
import torch
import pandas as pd
import numpy as np

# %% [markdown]
# # **SECTION 1: TENSOR BASICS (4–5 QUESTIONS)

# %%
def d(t1):
    print(t1)
    print(t1.dtype)

# %% [markdown]
# ## A. Create a 1D tensor with values [1, 2, 3, 4]

# %% [markdown]
# ## B. Create a 2D tensor (matrix) of shape (2, 3)

# %% [markdown]
# ## C. Create a tensor from a Python list [10, 20, 30]

# %% [markdown]
# ## D. Create a tensor of zeros with shape (3, 3)

# %% [markdown]
# ## E. Create a tensor of random values of shape (2, 2)

# %% [markdown]
# # SECTION 2: TENSOR SHAPE, DIMENSION & TYPE

# %% [markdown]
# ## A. Given tensor t = torch.randn(3, 4),
# print:
# 1. Shape
# 2. Number of dimensions

# %%
ten = torch.randn(3,4)

# %% [markdown]
# ## B. Change the dtype of a tensor from int to float

# %% [markdown]
# ## C. Reshape a tensor of shape (2, 3) into (3, 2)

# %% [markdown]
# ## D.  Create a scalar tensor and check its dimension

# %% [markdown]
# # SECTION 3: TENSOR OPERATIONS

# %% [markdown]
# ## A. Perform element-wise addition of two tensors

# %% [markdown]
# ## B. Perform matrix multiplication between:
#     A = (2x3), B = (3x2)

# %% [markdown]
# ## C. Multiply a tensor by a scalar (e.g., tensor * 5)

# %% [markdown]
# ## D. Find the mean of a tensor

# %% [markdown]
# ## E. Find the maximum value in a tensor

# %% [markdown]
# # SECTION 4: BROADCASTING

# %% [markdown]
# ## A. Add a tensor of shape (3, 1) with a tensor of shape (1, 3)

# %% [markdown]
# ## B.  Add a scalar to a tensor

# %% [markdown]
# ## C. Explain in one comment what broadcasting is

# %% [markdown]
# # SECTION 5: AUTOGRAD & GRADIENTS

# %% [markdown]
# ## A. Create a tensor with requires_grad=True

# %% [markdown]
# ## B. Compute y = x^2 where x requires gradient

# %% [markdown]
# ## C. Call backward() and print gradient of x

# %% [markdown]
# ## D. Why do we need gradients in deep learning?
#
#
# Answer ? Tell

# %% [markdown]
# ---

# %% [markdown]
# # SECTION 1: INDEXING, SLICING & MASKING

# %% [markdown]
# ## A.  Create a tensor [10, 20, 30, 40, 50]
# ###  Access the 3rd element

# %% [markdown]
# ## B. Slice first three elements from the tensor

# %% [markdown]
# ## C. Create a 2D tensor (3x3). Access element at row=1, col=2

# %% [markdown]
# ## D. Get all rows but only 2nd column

# %% [markdown]
# ## E. Create a tensor [1,2,3,4,5,6]
# ###   Select only even numbers using masking

# %% [markdown]
# ## F. Replace all values > 3 with 0

# %% [markdown]
# ## G. Check if a tensor contains value 4

# %% [markdown]
# ## I. Count number of elements > 2

# %% [markdown]
# # SECTION 2: SHAPE MANIPULATION (unsqueeze, squeeze)

# %% [markdown]
# ## A. Create tensor of shape (3,). Convert it to (1,3) using unsqueeze

# %% [markdown]
# ## B. Convert tensor (1,3) back to (3,)

# %% [markdown]
# ## C. Add dimension at index=1 to tensor (3,4)

# %% [markdown]
# # SECTION 3: SORTING & ORDERING

# %% [markdown]
# ## A. Create tensor [3,1,4,2]. Sort it in ascending order

# %% [markdown]
# ## B. Get indices that would sort the tensor

# %% [markdown]
# ## C. Sort tensor in descending order

# %% [markdown]
# ## D. Sort along rows of a 2D tensor

# %% [markdown]
# # SECTION 4: STACK, CONCAT, SPLIT

# %% [markdown]
# ## A. Stack two tensors [1,2] and [3,4] along dim=0

# %% [markdown]
# ## B. Stack same tensors along dim=1

# %% [markdown]
# ## C. Concat both Tensor

# %% [markdown]
# # SECTION 5: VIEW, RESHAPE, FLATTEN

# %% [markdown]
# ## A. Create tensor (2,3) and flatten it

# %% [markdown]
# ## B. Convert tensor (2,3,4) into (4,3,2)

# %% [markdown]
# # SECTION 6: TRANSPOSE & PERMUTE

# %% [markdown]
# ## A. Transpose a matrix (swap rows & columns)

# %% [markdown]
# ## B. Permute tensor dimensions from (2,3,4) → (3,2,4)

# %% [markdown]
# ---

# %% [markdown]
# # GPU Practise

# %% [markdown]
# ## A. Create a tensor on CPU and move it to GPU

# %% [markdown]
# ## B.  Create a tensor on GPU

# %% [markdown]
# ## C. Create a NumPy array [1,2,3,4]. Convert it to a PyTorch tensor. Move it to GPU

# %% [markdown]
# ## D. Create NumPy array
# ### Convert to tensor using from_numpy
# ### Modify tensor and observe NumPy arra

# %% [markdown]
# ## E. Why does this code fail?
# ### tensor.numpy()
# ### when tensor is on GPU?
# ### Write fix as code
